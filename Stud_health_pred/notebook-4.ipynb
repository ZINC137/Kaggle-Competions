# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
train = pd.read_csv("playground-series-s6e7/train.csv")
test = pd.read_csv("playground-series-s6e7/test.csv")

# %%
train.head()
# Out:
#    id health_condition  sleep_duration  heart_rate    bmi  \
# 0   0        unhealthy            5.22        70.6  25.66
# 1   1          at-risk            5.53        71.3  25.84
# 2   2        unhealthy            5.29        75.4  24.54
# 3   3        unhealthy            4.70        77.2  23.13
# 4   4          at-risk            7.23        73.4  28.44
#
#    calorie_expenditure  step_count  exercise_duration  water_intake diet_type  \
# 0               2174.0      1326.0               19.8          1.86       veg
# 1               1966.0      9891.0               49.9          1.26   non-veg
# 2               2688.0     14216.0               38.1          1.60       veg
# 3               2630.0      7174.0               59.9          2.02       veg
# 4               2560.0      6584.0               46.0          2.25       veg
#
#   stress_level sleep_quality physical_activity_level smoking_alcohol  gender
# 0         high       average               sedentary             yes  female
# 1          low       average                moderate             yes   other
# 2         high          poor                  active             yes    male
# 3         high       average                  active      occasional  female
# 4          NaN       average               sedentary             NaN    male

# %%
mapping = {
    "unhealthy": 0,
    "at-risk": 1,
    "fit": 2
}

train["health_condition"] = train["health_condition"].map(mapping)

# %%
train
# Out:
#             id  health_condition  sleep_duration  heart_rate    bmi  \
# 0            0                 0            5.22        70.6  25.66
# 1            1                 1            5.53        71.3  25.84
# 2            2                 0            5.29        75.4  24.54
# 3            3                 0            4.70        77.2  23.13
# 4            4                 1            7.23        73.4  28.44
# ...        ...               ...             ...         ...    ...
# 690083  690083                 1            6.31        69.7  24.11
# 690084  690084                 1            5.78        54.0  26.36
# 690085  690085                 2            7.64        85.7  21.91
# 690086  690086                 1            6.74        73.0  18.73
# 690087  690087                 1            5.55        69.3  24.38
#
#         calorie_expenditure  step_count  exercise_duration  water_intake  \
# 0                    2174.0      1326.0               19.8          1.86
# 1                    1966.0      9891.0               49.9          1.26
# 2                    2688.0     14216.0               38.1          1.60
# 3                    2630.0      7174.0               59.9          2.02
# 4                    2560.0      6584.0               46.0          2.25
# ...                     ...         ...                ...           ...
# 690083               2157.0         NaN               30.8          3.00
# 690084               2858.0      6488.0               52.4          1.46
# 690085               2195.0      9241.0               41.3          1.57
# 690086               2061.0     13366.0               56.6          2.60
# 690087               2257.0      5144.0               47.9          1.76
#
#        diet_type stress_level sleep_quality physical_activity_level  \
# 0            veg         high       average               sedentary
# 1        non-veg          low       average                moderate
# 2            veg         high          poor                  active
# 3            veg         high       average                  active
# 4            veg          NaN       average               sedentary
# ...          ...          ...           ...                     ...
# 690083   non-veg         high          poor                  active
# 690084       veg       medium       average                moderate
# 690085   non-veg          NaN       average                  active
# 690086  balanced          NaN       average                  active
# 690087  balanced       medium       average                moderate
#
#        smoking_alcohol  gender
# 0                  yes  female
# 1                  yes   other
# 2                  yes    male
# 3           occasional  female
# 4                  NaN    male
# ...                ...     ...
# 690083             yes  female
# 690084              no    male
# 690085              no    male
# 690086             yes    male
# 690087             yes    male
#
# [690088 rows x 15 columns]

# %%
y = train["health_condition"]

train = train.drop(columns=["health_condition"])

df = pd.concat([train, test], ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985841 entries, 0 to 985840
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       985841 non-null  int64
#  1   sleep_duration           877271 non-null  float64
#  2   heart_rate               974651 non-null  float64
#  3   bmi                      965987 non-null  float64
#  4   calorie_expenditure      910336 non-null  float64
#  5   step_count               965961 non-null  float64
#  6   exercise_duration        975982 non-null  float64
#  7   water_intake             923731 non-null  float64
#  8   diet_type                975982 non-null  object
#  9   stress_level             867540 non-null  object
#  10  sleep_quality            902511 non-null  object
#  11  physical_activity_level  933525 non-null  object
#  12  smoking_alcohol          945010 non-null  object
#  13  gender                   955308 non-null  object
# dtypes: float64(7), int64(1), object(6)
# memory usage: 105.3+ MB

# %%
stud_ids = test["id"].copy()

# %%
stud_ids.head()
# Out:
# 0    690088
# 1    690089
# 2    690090
# 3    690091
# 4    690092
# Name: id, dtype: int64

# %% [markdown]
# ## Filling Nulls

# %%
df.isna().sum()
# Out:
# id                              0
# sleep_duration             108570
# heart_rate                  11190
# bmi                         19854
# calorie_expenditure         75505
# step_count                  19880
# exercise_duration            9859
# water_intake                62110
# diet_type                    9859
# stress_level               118301
# sleep_quality               83330
# physical_activity_level     52316
# smoking_alcohol             40831
# gender                      30533
# dtype: int64

# %%
df.drop(columns='id',inplace=True)

# %%
num_cols = df.select_dtypes(include=["int64", "float64"]).columns
cat_cols = df.select_dtypes(include="object").columns

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

for col in cat_cols:
    df[col] = df[col].fillna("unknown")

# %%
df.isnull().sum()
# Out:
# sleep_duration             0
# heart_rate                 0
# bmi                        0
# calorie_expenditure        0
# step_count                 0
# exercise_duration          0
# water_intake               0
# diet_type                  0
# stress_level               0
# sleep_quality              0
# physical_activity_level    0
# smoking_alcohol            0
# gender                     0
# dtype: int64

# %%
df.shape
# Out:
# (985841, 13)

# %%
train_df = df.iloc[:len(y)].copy()
test_df = df.iloc[len(y):].copy()

# %%
train_df
# Out:
#         sleep_duration  heart_rate    bmi  calorie_expenditure  step_count  \
# 0                 5.22        70.6  25.66               2174.0      1326.0
# 1                 5.53        71.3  25.84               1966.0      9891.0
# 2                 5.29        75.4  24.54               2688.0     14216.0
# 3                 4.70        77.2  23.13               2630.0      7174.0
# 4                 7.23        73.4  28.44               2560.0      6584.0
# ...                ...         ...    ...                  ...         ...
# 690083            6.31        69.7  24.11               2157.0      8856.0
# 690084            5.78        54.0  26.36               2858.0      6488.0
# 690085            7.64        85.7  21.91               2195.0      9241.0
# 690086            6.74        73.0  18.73               2061.0     13366.0
# 690087            5.55        69.3  24.38               2257.0      5144.0
#
#         exercise_duration  water_intake diet_type stress_level sleep_quality  \
# 0                    19.8          1.86       veg         high       average
# 1                    49.9          1.26   non-veg          low       average
# 2                    38.1          1.60       veg         high          poor
# 3                    59.9          2.02       veg         high       average
# 4                    46.0          2.25       veg      unknown       average
# ...                   ...           ...       ...          ...           ...
# 690083               30.8          3.00   non-veg         high          poor
# 690084               52.4          1.46       veg       medium       average
# 690085               41.3          1.57   non-veg      unknown       average
# 690086               56.6          2.60  balanced      unknown       average
# 690087               47.9          1.76  balanced       medium       average
#
#        physical_activity_level smoking_alcohol  gender
# 0                    sedentary             yes  female
# 1                     moderate             yes   other
# 2                       active             yes    male
# 3                       active      occasional  female
# 4                    sedentary         unknown    male
# ...                        ...             ...     ...
# 690083                  active             yes  female
# 690084                moderate              no    male
# 690085                  active              no    male
# 690086                  active             yes    male
# 690087                moderate             yes    male
#
# [690088 rows x 13 columns]

# %% [markdown]
# ## Feature Engineering

# %%
## Numerical columns
df["exercise_water_ratio"] = (
    df["exercise_duration"] / (df["water_intake"] + 1)
)

df["water_per_calorie"] = df["water_intake"] / (df["calorie_expenditure"] + 1)

df["sleep_per_exercise"] = df["sleep_duration"] / (df["exercise_duration"] + 1)

df["bmi_activity"] = (
    df["bmi"] * df["exercise_duration"]
)
df["hydration_score"] = (
    df["water_intake"] * df["sleep_duration"]
)
df["heart_rate_efficiency"] = (
    df["calorie_expenditure"] / (df["heart_rate"] + 1)
)
df["recovery_ratio"] = (
    df["sleep_duration"]
    / (df["calorie_expenditure"] + 1)
)

# %%
df["diet_activity"] = (
    df["diet_type"].astype(str)
    + "_"
    + df["physical_activity_level"].astype(str)
)

df["stress_sleep"] = (
    df["stress_level"].astype(str)
    + "_"
    + df["sleep_quality"].astype(str)
)

df["gender_activity"] = (
    df["gender"].astype(str)
    + "_"
    + df["physical_activity_level"].astype(str)
)

df["diet_smoking"] = (
    df["diet_type"].astype(str)
    + "_"
    + df["smoking_alcohol"].astype(str)
)

# %%
cat_cols = df.select_dtypes(include="object").columns

for col in cat_cols:
    freq = df[col].value_counts()

    df[col + "_freq"] = df[col].map(freq)

# %%
df.head()
# Out:
#    sleep_duration  heart_rate    bmi  calorie_expenditure  step_count  \
# 0            5.22        70.6  25.66               2174.0      1326.0
# 1            5.53        71.3  25.84               1966.0      9891.0
# 2            5.29        75.4  24.54               2688.0     14216.0
# 3            4.70        77.2  23.13               2630.0      7174.0
# 4            7.23        73.4  28.44               2560.0      6584.0
#
#    exercise_duration  water_intake diet_type stress_level sleep_quality  ...  \
# 0               19.8          1.86       veg         high       average  ...
# 1               49.9          1.26   non-veg          low       average  ...
# 2               38.1          1.60       veg         high          poor  ...
# 3               59.9          2.02       veg         high       average  ...
# 4               46.0          2.25       veg      unknown       average  ...
#
#   diet_type_freq stress_level_freq sleep_quality_freq  \
# 0         330502            253578             305247
# 1         321110            239575             305247
# 2         330502            253578             303470
# 3         330502            253578             305247
# 4         330502            118301             305247
#
#    physical_activity_level_freq  smoking_alcohol_freq  gender_freq  \
# 0                        315754                319011       310236
# 1                        316529                319011       304881
# 2                        301242                319011       340191
# 3                        301242                311630       310236
# 4                        315754                 40831       340191
#
#    diet_activity_freq  stress_sleep_freq  gender_activity_freq  \
# 0              106846              78819                100072
# 1              101534              73925                 99867
# 2               99783              82330                104895
# 3               99783              78819                 95065
# 4              106846              36734                108924
#
#    diet_smoking_freq
# 0             107104
# 1             104144
# 2             107104
# 3             104491
# 4              13790
#
# [5 rows x 34 columns]

# %% [markdown]
# ## 5-fold CV with Target Encoding

# %%
from sklearn.model_selection import StratifiedKFold
from category_encoders import TargetEncoder
from lightgbm import LGBMClassifier
from sklearn.metrics import balanced_accuracy_score
import numpy as np

# %%
X = train_df.copy()
y = y.copy()          
X_test = test_df.copy()

# %%
cat_cols = X.select_dtypes(include="object").columns.tolist()

print(cat_cols)
# Out:
# ['diet_type', 'stress_level', 'sleep_quality', 'physical_activity_level', 'smoking_alcohol', 'gender']

# %%
skf = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %%
oof_preds = np.zeros(len(X))

test_preds = np.zeros((len(X_test), 3))

# %%
for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):

    print(f"Fold {fold}")

    X_train = X.iloc[train_idx].copy()
    X_val = X.iloc[val_idx].copy()

    y_train = y.iloc[train_idx]
    y_val = y.iloc[val_idx]
# Out:
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# Fold 5

# %%
encoder = TargetEncoder(cols=cat_cols)

X_train[cat_cols] = encoder.fit_transform(
    X_train[cat_cols],
    y_train
)

X_val[cat_cols] = encoder.transform(
    X_val[cat_cols]
)

X_test_encoded = X_test.copy()

X_test_encoded[cat_cols] = encoder.transform(
    X_test_encoded[cat_cols]
)

# %% [markdown]
# ## Models

# %% [markdown]
# ## 1.LightBGM

# %%
model = LGBMClassifier(
    objective="multiclass",
    num_class=3,
    n_estimators=500,
    learning_rate=0.05,
    random_state=42
)

model.fit(
    X_train,
    y_train
)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015761 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1814
# [LightGBM] [Info] Number of data points in the train set: 552071, number of used features: 13
# [LightGBM] [Info] Start training from score -2.481130
# [LightGBM] [Info] Start training from score -0.152368
# [LightGBM] [Info] Start training from score -2.852859
# LGBMClassifier(learning_rate=0.05, n_estimators=500, num_class=3,
#                objective='multiclass', random_state=42)

# %%
val_pred = model.predict(X_val)

oof_preds[val_idx] = val_pred

# %%
test_preds += model.predict_proba(X_test_encoded) / skf.n_splits

# %%
score = balanced_accuracy_score(y, oof_preds)

print(f"CV Balanced Accuracy : {score:.5f}")
# Out:
# CV Balanced Accuracy : 0.44205

# %% [markdown]
# ## submission

# %%
final_pred = np.argmax(test_preds, axis=1)

# %%
inverse_mapping = {
    0: "unhealthy",
    1: "at-risk",
    2: "fit"
}

submission = pd.DataFrame({
    "id": stud_ids,
    "health_condition": pd.Series(final_pred).map(inverse_mapping)
})

# %%
submission.head()
# Out:
#        id health_condition
# 0  690088        unhealthy
# 1  690089          at-risk
# 2  690090          at-risk
# 3  690091          at-risk
# 4  690092        unhealthy

# %%
submission.to_csv("submission.csv",index=False)
